# %%
# %%writefile test.cpp
# #include <iostream>
# using namespace std;
# int main()
# {
#     cout <<"hello, world to you"<<endl;
#     return 0;
# }
# Out:
# Writing test.cpp

# %%
# !ls
# Out:
# sample_data  test.cpp

# %%
# %%shell
# g++ test.cpp -o bout
# ./bout
# Out:
# hello, world to you
