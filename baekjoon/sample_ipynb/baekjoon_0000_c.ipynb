# %%
# %%writefile test.cpp
# #include <stdio.h>
# int main(void)
# {
#     printf("hello, world to you \n");
#     return 0;
# }
# Out:
# Writing test.cpp

# %%
# !ls
# Out:
# b.cpp  sample_data  test.cpp

# %%
# %%shell
# g++ test.cpp -o testexe
# ./testexe
# Out:
# hello, world to you
